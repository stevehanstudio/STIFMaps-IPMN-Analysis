# %%
# Import from the globals_and_helpers file
from globals_and_helpers import (
    # generate_colormap_legend,
    calc_crop_dimensions,
    crop_STIFMap,
    scale_annotations,
    filter_measurements,
    gen_report,
)

# %%
# generate_colormap_legend(2)

# %%
# calc_crop_dimensions("27620")
# calc_crop_dimensions("7002")
calc_crop_dimensions("4601")
# Out:
# File: 4601_C0_full.tif, Dimensions: 36889x27744
# Original DAPI Image Dimensions: 36889x27744
# Original STIFMap Image Dimensions: 2816x2112
# Cropped Image Dimensions: 2595x1952
# orig_width: 36889, orig_height: 27744, scaling_factor: 14.213068181818182
# (2595, 1952)

# %%
# crop_STIFMap("7002")
crop_STIFMap("4601")
# Out:
# File: 4601_C0_full.tif, Dimensions: 36889x27744
# Original DAPI Image Dimensions: 36889x27744
# Original STIFMap Image Dimensions: 2816x2112
# Cropped Image Dimensions: 2595x1952
# orig_width: 36889, orig_height: 27744, scaling_factor: 14.213068181818182
# Grayscale image saved to c:\Users\steve\Projects\WeaverLab\STIFMaps-IPMN-Analysis\final_outputs\4601_STIFMap_stitched_cropped_gray.png

# %%
# This step must be runned after exporting Annotations objects as GeoJSON in QuPath
# The output of this is used import the annotations in to QuPath on the scaled grayscal image
scale_annotations("4601")
# Out:
# Number of features in GeoJSON: 21
# File: 4601_C0_full.tif, Dimensions: 36889x27744
# File: 4601_C0_full.tif, Dimensions: 36889x27744
# Original DAPI Image Dimensions: 36889x27744
# Original STIFMap Image Dimensions: 2816x2112
# Cropped Image Dimensions: 2595x1952
# orig_width: 36889, orig_height: 27744, scaling_factor: 14.213068181818182
# Scaled annotations saved to: c:\Users\steve\Projects\WeaverLab\STIFMaps-IPMN-Analysis\../analysis_panel_1\4601_scaled_annotations.geojson

# %%
filter_measurements("4601")
# Out:
#                                Object ID Classification       ROI  \
# 0   aac27887-0b37-4b7f-b37f-c6086c973967            HGD   Polygon
# 1   074244f9-ca58-41b0-bb34-beff232c956b     HGD_manual   Polygon
# 2   53ed2d07-b470-4a86-8158-dad05009c9fe     HGD_manual   Polygon
# 3   7dd01d3a-8934-4ef9-93c1-3c40599dc07c            HGD  Geometry
# 4   0525a380-b118-447f-9d5f-1476e72748b5            HGD   Polygon
# 5   ab69c066-0e9f-43ff-81a5-cce732a76640            HGD   Polygon
# 6   7c97f4ab-ac52-40d0-ac0e-0837a4d2b2bc            HGD   Polygon
# 7   dbd8bc93-4efc-4f93-8d42-26d3a9488b41     background   Polygon
# 8   98dbb333-3c24-48bf-81de-5f6f69b88a37     background   Polygon
# 9   84d74027-196c-4b32-b1df-8bf7350ffdc9     background   Polygon
# 10  e9452bea-df97-4eaf-8c6c-66abf63d4027     background   Polygon
# 11  9fa174aa-9a49-40e8-93f6-a41e67467016     background   Polygon
# 12  383ad4d8-ac8d-4cef-8649-79e144067dba     background   Polygon
# 13  8192e04f-f0e6-4b81-9c86-e0b47af37239     background   Polygon
# 14  423521eb-8bf7-4559-a51e-01a0ec622503     background   Polygon
# 15  92f06b02-a028-4728-9b23-bce8dd764af1     background   Polygon
# 16  43c7f2f9-6c4a-41ff-bb78-6770ec1ccd7a     background   Polygon
# 17  96f23f23-eba1-4b67-a495-5744656a2811     background   Polygon
# 18  101f6f92-fa5e-4d54-a55c-f04e5e75c940     background   Polygon
# 19  901190d8-c35d-468f-81e2-e08ed3f783bd     background   Polygon
# 20  fb1661e0-eef5-4471-bf6b-0e091b3891e2     background   Polygon
#
#     ROI: 1.00 px per pixel: Channel 1: Mean
# 0                                   73.1771
# 1                                  144.4246
# 2                                  158.5598
# 3                                   50.6541
# 4                                   91.0932
# 5                                   98.6098
# 6                                   94.5128
# 7                                   38.2977
# 8                                   46.2405
# 9                                   55.6771
# 10                                  38.2220
# 11                                  53.7438
# 12                                  50.8778
# 13                                  45.5218
# 14                                  45.9987
# 15                                  46.9505
# 16                                 184.2754
# 17                                 179.4471
# 18                                  35.4614
# 19                                 176.3888
# 20                                 171.7018
